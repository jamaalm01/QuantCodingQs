# %%
def no_duplicates(nums):
    hashset = {*()}
    for n in nums:
        if (n in hashset):
            return False
        else:
            hashset.add(n)
    
    return True

# %%
nums = [1,3,2,4,5]

# %%
no_duplicates(nums)
# Out:
# True
