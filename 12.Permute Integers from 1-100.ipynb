# %%
import random

def permute():
    numList = [0 for i in range(100)]
    for i in range(100):
        number = random.randint(1,100)
        while (number in numList):
            number = random.randint(1,100)
        numList[i] = number
    
    return numList

# %%
permute()
# Out:
# [22,
#  98,
#  79,
#  28,
#  50,
#  11,
#  12,
#  14,
#  91,
#  31,
#  95,
#  59,
#  51,
#  46,
#  8,
#  55,
#  92,
#  26,
#  20,
#  100,
#  47,
#  71,
#  70,
#  81,
#  84,
#  39,
#  56,
#  94,
#  44,
#  36,
#  53,
#  34,
#  69,
#  4,
#  45,
#  42,
#  41,
#  76,
#  87,
#  86,
#  13,
#  65,
#  32,
#  37,
#  43,
#  57,
#  18,
#  72,
#  23,
#  96,
#  29,
#  68,
#  33,
#  7,
#  67,
#  61,
#  85,
#  15,
#  30,
#  24,
#  52,
#  64,
#  63,
#  89,
#  19,
#  82,
#  80,
#  35,
#  6,
#  66,
#  2,
#  48,
#  62,
#  97,
#  54,
#  88,
#  75,
#  77,
#  40,
#  73,
#  78,
#  74,
#  25,
#  3,
#  16,
#  49,
#  1,
#  99,
#  5,
#  90,
#  58,
#  83,
#  60,
#  10,
#  38,
#  27,
#  21,
#  9,
#  17,
#  93]
